# %%
from google import genai

client = genai.Client(api_key="AIzaSyDCLQSiHQfXwtbpQ8Uf6AH6DZe6Zz6nOAs")

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works in a few words"
)
print(response.text)
# prompt_template = f"""
# You are an expert financial analyst AI. Your task is to analyze the provided list of news articles to generate investment recommendations.

# Follow these steps precisely:
# 1.  Read through the entire JSON array of articles provided below.
# 2.  For each article, identify the primary companies mentioned and the sentiment of the news (Positive, Negative, or Neutral) regarding each company's business prospects.
# 3.  Synthesize the findings for each company across all articles they appear in.
# 4.  Based on the overall sentiment and the potential business impact described, select the 5 most promising stocks to invest in. For each, provide a stock ticker if it's a well-known public company.
# 5.  Provide a concise 'reasoning' for each recommendation, directly referencing the news content.
# 6.  Identify at least two 'stocksToAvoid' based on negative news and provide the reasoning.
# 7.  Your final output must be a single, valid JSON object and nothing else. Do not include any text or explanations before or after the JSON block.

# Here is the required JSON output structure:

# {{
#   "investmentAnalysis": {{
#     "stocksToInvest": [
#       {{
#         "companyName": "Example Company A",
#         "stockTicker": "EXA",
#         "reasoning": "A brief, data-driven reason based on the provided articles."
#       }}
#     ],
#     "stocksToAvoid": [
#       {{
#         "companyName": "Example Company B",
#         "stockTicker": "EXB",
#         "reasoning": "A brief, data-driven reason based on the provided articles."
#       }}
#     ]
#   }}
# }}

# ---
# Here are the news articles:

# {news_articles_json}
# """

# # 4. --- Prepare the Request Body ---
# # The body must be a JSON object that follows the Gemini API's structure.
# # We also specify that the output must be JSON.
# request_body = {
#   "contents": [{
#     "parts": [{
#       "text": prompt_template
#     }]
#   }],
#   "generationConfig": {
#     "responseMimeType": "application/json"
#   }
# }

# # 5. --- Make the API Call ---
# try:
#     response = requests.post(API_URL, json=request_body, headers={"Content-Type": "application/json"})
    
#     # Raise an exception if the request was unsuccessful
#     response.raise_for_status() 
    
#     # 6. --- Print the Result ---
#     # The API returns a JSON object; we extract the generated text from it.
#     response_data = response.json()
#     generated_json = response_data['candidates'][0]['content']['parts'][0]['text']
    
#     # Pretty-print the JSON for readability
#     parsed_json = json.loads(generated_json)
#     print(json.dumps(parsed_json, indent=2))

# except requests.exceptions.RequestException as e:
#     print(f"An error occurred: {e}")
#     # If the response contains error details, print them
#     if e.response:
#         print("Error details:", e.response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[4], line 5
#       1 from google import genai
#       3 client = genai.Client(api_key="YOUR_API_KEY")
# ----> 5 response = client.models.generate_content(
#       6     model="gemini-2.5-flash", contents="Explain how AI works in a few words"
#       7 )
#       8 print(response.text)
#       9 # prompt_template = f"""
#      10 # You are an expert financial analyst AI. Your task is to analyze the provided list of news articles to generate investment recommendations.
#      11
#    (...)     81 #     if e.response:
#      82 #         print("Error details:", e.response.text)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\genai\models.py:5821, in Models.generate_content(self, model, contents, config)
#    5819 while remaining_remote_calls_afc > 0:
#    5820   i += 1
# -> 5821   response = self._generate_content(
#    5822       model=model, contents=contents, config=parsed_config
#    5823   )
#    5824   logger.info(f'AFC remote call {i} is done.')
#    5825   remaining_remote_calls_afc -= 1
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\genai\models.py:4780, in Models._generate_content(self, model, contents, config)
#    4777 request_dict = _common.convert_to_dict(request_dict)
#    4778 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4780 response = self._api_client.request(
#    4781     'post', path, request_dict, http_options
#    4782 )
#    4784 response_dict = '' if not response.body else json.loads(response.body)
#    4786 if self._api_client.vertexai:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\genai\_api_client.py:986, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#     976 def request(
#     977     self,
#     978     http_method: str,
#    (...)    981     http_options: Optional[HttpOptionsOrDict] = None,
#     982 ) -> SdkHttpResponse:
#     983   http_request = self._build_request(
#     984       http_method, path, request_dict, http_options
#     985   )
# --> 986   response = self._request(http_request, stream=False)
#     987   response_body = response.response_stream[0] if response.response_stream else ''
#     988   return SdkHttpResponse(
#     989       headers=response.headers, body=response_body
#     990   )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\genai\_api_client.py:879, in BaseApiClient._request(self, http_request, stream)
#     874 def _request(
#     875     self,
#     876     http_request: HttpRequest,
#     877     stream: bool = False,
#     878 ) -> HttpResponse:
# --> 879   return self._retry(self._request_once, http_request, stream)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tenacity\__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tenacity\__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tenacity\__init__.py:418, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     416 retry_exc = self.retry_error_cls(fut)
#     417 if self.reraise:
# --> 418     raise retry_exc.reraise()
#     419 raise retry_exc from fut.exception()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tenacity\__init__.py:185, in RetryError.reraise(self)
#     183 def reraise(self) -> t.NoReturn:
#     184     if self.last_attempt.failed:
# --> 185         raise self.last_attempt.result()
#     186     raise self
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tenacity\__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\genai\_api_client.py:869, in BaseApiClient._request_once(self, http_request, stream)
#     861 else:
#     862   response = self._httpx_client.request(
#     863       method=http_request.method,
#     864       url=http_request.url,
#    (...)    867       timeout=http_request.timeout,
#     868   )
# --> 869   errors.APIError.raise_for_response(response)
#     870   return HttpResponse(
#     871       response.headers, response if stream else [response.text]
#     872   )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\genai\errors.py:104, in APIError.raise_for_response(cls, response)
#     102 status_code = response.status_code
#     103 if 400 <= status_code < 500:
# --> 104   raise ClientError(status_code, response_json, response)
#     105 elif 500 <= status_code < 600:
#     106   raise ServerError(status_code, response_json, response)
#
# ClientError: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'API key not valid. Please pass a valid API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key not valid. Please pass a valid API key.'}]}}
